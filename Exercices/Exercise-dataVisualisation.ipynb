# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
petite_1 = np.array([1.36, 0.24, 0.22, 0.11 ,1.25, 0.24, 0.35, 0.24, 1.60, 0.63, 0.68 ,0.00, 1.44, 1.86 ,3.47, 0.58, 0.00, 0.82, 2.75, 3.14, 1.58, 2.83, 1.92, 0.83, 2.47, 1.13, 1.72, 0.61, 0.35, 1.11, 1.24, 2.36, 0.50])
moyenne_1 = np.array([2.07, 3.60, 2.57, 4.29, 5.67, 1.67, 2.43, 4.72, 7.67, 3.83, 5.13, 2.31, 1.00, 3.74, 6.64, 3.39, 2.36, 6.75, 5.13, 8.00, 7.08, 6.01, 6.25, 2.61, 3.61, 2.67, 5.24, 1.56, 1.89, 4.06, 3.11, 4.00, 2.89])
grande_1 = np.array([7.63, 5.79, 7.38, 8.50, 5.75, 4.83, 5.38, 7.75, 7.54, 8.38, 7.50, 6.17, 5.68, 7.25, 7.54, 5.64, 6.46, 7.50, 8.75, 9.00, 7.25, 7.42, 6.58, 8.25, 7.46, 7.21, 7.50, 8.17 ,6.96 ,8.00, 6.92, 5.71, 7.00])
petite_2= np.array([1.57, 1.36, 1.25, 2.81, 0.86, 0.47, 0.35, 1.81, 1.63, 1.36, 0.35, 1.75, 0.35, 2.58, 1.58, 1.67, 0.60, 1.63, 1.06, 0.00, 2.17, 0.25, 0.00, 2.67, 2.33, 1.13, 1.22, 1.33, 1.00, 0.83])
moyenne_2 = np.array([2.26, 3.68, 6.26, 3.88, 6.54, 5.25, 6.00, 6.67, 4.96, 2.57, 1.64, 5.83, 6.42, 6.88, 4.46, 1.94, 5.50, 1.71, 3.33, 2.28, 5.67, 5.32, 1.56, 2.32, 4.17, 6.18, 4.32, 6.50, 3.00, 2.67])
grande_2 = np.array([4.42, 6.63, 6.88, 7.17, 7.00, 7.33, 7.63, 6.54, 8.54, 5.21, 4.46, 7.00, 6.50, 6.00, 7.25, 5.47, 7.63, 3.83, 4.92, 5.96, 6.33, 7.13, 4.61, 4.13, 7.00 ,7.25, 7.88, 8.50, 5.21, 7.00])

# %% [markdown]
# # Exercice: Data vizualisation

# %% [markdown]
# ## 1. Evaluation de chaque étudiant au file des 3 ans

# %% [markdown]
# ## 1.1 Groupe 1

# %%
# %matplotlib inline
plt.figure(figsize=(10, 4), dpi=80)
plt.plot(range(len(petite_1)), petite_1, label="petite")
plt.plot (range(len(petite_1)), moyenne_1, label="moyenne")
plt.plot(range(len(petite_1)), grande_1, label="grande")

plt.xlabel("Indice des éléves")
plt.ylabel("Notes")
plt.title("Groupe 1")
plt.legend()

# %% [markdown]
# Le graphe ci-dessus montre clairement que tous les étudiants qu'ils soient de niveau moyen ou bon se sont tous améliorés au file des ans.
# Certains ont pratiquement gardé le même classement, d'autres ont triplé d''efforts et ont gagné un nombre de place important dans le classement du groupe 1.

# %% [markdown]
# ## 1.2. Groupe 2

# %%
plt.figure(figsize=(10, 4), dpi=80)
plt.plot(range(len(petite_2)), petite_2, label="petite")
plt.plot (range(len(petite_2)), moyenne_2, label="moyenne")
plt.plot(range(len(petite_2)), grande_2, label="grande")

plt.xlabel("Eleves")
plt.ylabel("Notes")
plt.title("Groupe 2")
plt.legend()

# %% [markdown]
# Contrairement au groupe 1, certains éléves ne se sont pas forcément améliorés au fil des années, comme on peut le voir dans le graphe ci-dessus pour la 2éme et la 3éme année pour l'éléve ayant majoré durant sa 2éme année.
# Sinon, la grande majorité des éléves ont similairement au groupe 1 eu de meilleures notes comparées à celles obtenues dans les années qui avaient précédé.

# %% [markdown]
# ## 2. Evaluation des deux groupes

# %%
maxp1 = np.amax(petite_1)
maxp2 = np.amax(petite_2)

maxm1 = np.amax(moyenne_1)
maxm2 = np.amax(moyenne_2)

maxg1 = np.amax(grande_1)
maxg2 = np.amax(grande_2)

# %%
minp1 = np.amin(petite_1)
minp2 = np.amin(petite_2)

minm1 = np.amin(moyenne_1)
minm2 = np.amin(moyenne_2)

ming1 = np.amin(grande_1)
ming2 = np.amin(grande_2)

# %%
meanp1 = petite_1.mean()
meanp2 = petite_2.mean()

meanm1 = moyenne_1.mean()
meanm2 = moyenne_2.mean()

meang1 = grande_1.mean()
meang2 = grande_2.mean()

# %%
medianp1 = np.median(petite_1)
medianp2 = np.median(petite_2)

medianm1 = np.median(moyenne_1)
medianm2 = np.median(moyenne_2)

mediang1 = np.median(grande_1)
mediang2 = np.median(grande_2)

# %%
plt.figure(figsize=(10, 5), dpi=80)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2,  constrained_layout=True, figsize=(18,8))
fig.subplots_adjust(left=0.2, wspace=0.3, hspace = 0.5)



my_xticks = ["petite",'moyenne',"grande"]
ax1.set_xticks([1,2,3])
ax1.set_xticklabels(my_xticks, minor=False)

ax1.plot([1,2,3], [maxp1, maxm1, maxg1],'-bo' , color = 'g', label="Groupe 1" )
ax1.plot([1,2,3], [maxp2, maxm2, maxg2], '-bo' , label = "Groupe 2")
ax1.set_ylabel("Note")
ax1.set_xlabel("Année")
ax1.set_title("Note maximum")
ax1.legend()

ax2.set_xticks([1,2,3])
ax2.set_xticklabels(my_xticks, minor=False)

ax2.plot([1,2,3], [minp1, minm1, ming1],'-bo' , color = 'g', label="Groupe 1" )
ax2.plot([1,2,3], [minp2, minm2, ming2], '-bo' , label = "Groupe 2")
ax2.set_ylabel("Note")
ax2.set_xlabel("Année")
ax2.set_title("Note minimum")
ax2.legend()


ax3.set_xticks([1,2,3])
ax3.set_xticklabels(my_xticks, minor=False)

ax3.plot([1,2,3], [medianp1, medianm1, mediang1],'-bo' , color = 'g', label="Groupe 1" )
ax3.plot([1,2,3], [medianp2, medianm2, mediang2], '-bo' , label = "Groupe 2")
ax3.set_ylabel("Note")
ax3.set_xlabel("Année")
ax3.set_title("Note médiane")
ax3.legend()

ax4.set_xticks([1,2,3])
ax4.set_xticklabels(my_xticks, minor=False)

ax4.plot([1,2,3], [meanp1, meanm1, meang1],'-bo' , color = 'g', label="Groupe 1" )
ax4.plot([1,2,3], [meanp2, meanm2, meang2], '-bo' , label = "Groupe 2")
ax4.set_ylabel("Note")
ax4.set_xlabel("Année")
ax4.set_title("Note moyenne")
ax4.legend()

plt.show()
# Out:
# C:\Users\SNOW\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ### Interpretation
# On peut trés clairement voir qu'en ce qui concerne les caractéristiques du groupe en terme de note minimale, médiane et moyenne, les deux groupes malgré la différence du nombre d'éléves s'y trouvant sont similaire durant la petite section. Ce qui change l'année suivante car le groupe 2 se démarque et dépasse légérement le groupe 1. Puis c'est au tour du groupe 1 de prendre le dessus durant la grande section.
# Quant à la note maximalen quelque soit la section (petite, moyenne ou grande), le groupe 1 dépassé chaque année un peu plus le groupe 2.

# %% [markdown]
# #  Exercise : Getting the (wrong) picture from the data : Correlation and causality

# %%
dic = {17.5: [15, 18, 19, 20], 18: [16, 17, 18, 19], 18.5: [14, 16, 17], 19: [15, 16], 20: [13, 14, 15], 20.5: [12, 13, 14], 21: [10, 11, 13, 15], 21.5: [10, 12, 13], 22: [8, 10, 11, 12], 23: [8, 9, 10], 23.5: [7, 8, 9, 11], 24: [6, 8, 9], 24.5: [6, 7, 8, 10], 25: [4, 6, 7, 8], 25.5: [5, 6], 26: [4, 5, 7], 26.5: [3, 4, 5], 27: [2, 3, 4, 7], 27.5: [2, 3], 28: [0, 1, 2, 4], 28.5: [0, 2], 29: [0, 1, 2]}

# %%
feet_size = np.array([17.5, 17.5, 17.5, 17.5, 18, 18 ,18 ,18, 18.5, 18.5, 18.5 ,19, 19, 20, 20, 20, 20.5, 20.5, 20.5, 20.5, 21, 21, 21, 21, 21.5, 21.5, 21.5, 22 ,22, 22 ,22 ,23, 23, 23 ,23.5, 23.5, 23.5 ,23.5, 24, 24 ,24, 24.5, 24.5, 24.5, 24.5, 25, 25, 25, 25 ,25.5, 25.5, 26, 26, 26, 26.5, 26.5, 26.5, 27 ,27 ,27 ,27 ,27.5, 27.5, 28, 28 ,28 ,28])

mistakes = np.array([15, 18, 19, 20, 16 ,17 ,18, 19 ,14 ,16, 17 ,15 ,16 ,13, 14 ,15, 12, 13, 14 ,15 ,10 ,11 ,13 ,15 ,10, 12 ,13, 8 ,10 ,11 ,12, 8 ,9 ,10 ,7 ,8 ,9 ,11, 6 ,8 ,9, 6 ,7, 8, 10, 4 ,6 ,7, 8, 5, 6, 4, 5, 7, 3, 4, 5, 2, 3, 4, 7, 2, 3, 0 ,1 ,2, 4])

# %%
plt.figure(figsize=(10, 4), dpi=80)
plt.plot(feet_size, mistakes,'o'  )


plt.xlabel("feet size")
plt.ylabel("mistakes")
plt.title("relationship between feet size and made mistakes")
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Note:
# each point represents a child

# %% [markdown]
# ### Interpretation
# At first sight, without knowing the context and based only on the graph we could think that there's a correclation between the variables reprenseted in both axis x and y.
# However, when we go deeper by looking for more information about the data represented, we conclude that it may not be a correlation between both feet size and the mistakes made by each child. Because, it would a bit strange to say that students with larger feet size do less mistakes. Even if it's the case, it's necessary to look for more information about this case study to discover if there's any another missed key data that would explain the correlation or cancel it.
